# %%
###remove case sensitivity
#input file is ds.csv

import hashlib

'''
hashlib.md5('heroine'.encode()).hexdigest()
hashlib.sha256('poftutcom'.encode()).hexdigest()
hashlib.sha512('poftutcom'.encode()).hexdigest()


to do hashing in group, you can use the following command
for h in map(hashlib.sha256,['poftut.com'.encode(),'ismail'.encode(),'ali'.encode()]):
 h.hexdigest()
'''

countries = ['India',
'China',
'Pakistan',
'Bangladesh',
'Afghanistan']

events=['Civil unrest',
'Attack',
'Disease outbreak',
'Flood']

months=['January',
'February',
'March',
'April',
'May',
'June',
'July',
'August',
'September',
'October',
'November',
'December']
#Provinces of Pakistan
provincePak= ['Sindh',
'Punjab',
'Balochistan',
'Khyber Pakhtunkhwa',
'Gilgit Baltistan',
'Azad Kashmir',
'Islamabad']
#Provinces of China:

provinceChina=['Qinghai',
'Sichuan',
'Gansu',
'Heilongjiang',
'Yunnan',
'Hunan',
'Shaanxi',
'Hebei',
'Jilin',
'Hubei',
'Hubei',
'Guizhou',
'Guangdong',
'Jiangxi',
'Henan',
'Shanxi',
'Shandong',
'Liaoning',
'Anhui',
'Fujian',
'Jiangsu',
'Zhejiang',
'Taiwan',
'Hainan',
'Hong Kong',
'Tibet',
'Beijing',
'Xinjiang',
'Suzhou']

provinceIndia =['Andhra Pradesh',
                'Arunachal Pradesh',
                'Assam',
                'Bihar',
                'Chhattisgarh',
                'Goa',
                'Gujarat',
                'Haryana',
                'Himachal Pradesh',
                'Jharkhand',
                'Karnataka',
                'Kerala',
                'Madhya Pradesh',
                'Maharashtra',
                'Manipur',
                'Meghalaya',
                'Mizoram',
                'Nagaland',
                'Odisha',
                'Punjab',
                'Rajasthan',
                'Sikkim',
                'Tamil Nadu',
                'Telangana',
                'Tripura',
                'Uttar Pradesh',
                'Uttarakhand',
                'West Bengal',
                'Andaman and Nicobar Islands',
                'Chandigarh',
                'Dadra & Nagar Haveli and Daman & Diu',
                'Delhi',
                'Kashmir',#
                'Lakshadweep',
                'Puducherry',
                'Ladakh']

# %%
dCountries = {}
dEvents = {}
dProvincePak = {}
dProvinceChina = {}
dProvinceIndia = {}
dMonths = {}

for a in countries:
    dCountries[a] = int(hashlib.sha512(a.encode()).hexdigest()[0:10], 16)
    
for a in months:
    dMonths[a] = int(hashlib.sha512(a.encode()).hexdigest()[0:10], 16)
    
for a in events:
    dEvents[a] = int(hashlib.sha512(a.encode()).hexdigest()[0:10], 16)
    
for a in provincePak:
    dProvincePak[a] = int(hashlib.sha512(a.encode()).hexdigest()[0:10], 16)
    
for a in provinceChina:
    dProvinceChina[a] = int(hashlib.sha512(a.encode()).hexdigest()[0:10], 16)

for a in provinceIndia:
    dProvinceIndia[a] = int(hashlib.sha512(a.encode()).hexdigest()[0:10], 16)
    

#merging dictionaries for province
dProvince = {**dProvincePak, **dProvinceChina, **dProvinceIndia}

# %%
dCountries,dEvents,dMonths, dProvince
# Out:
# ({'India': 599540218941,
#   'China': 922074254021,
#   'Pakistan': 805650366791,
#   'Bangladesh': 550924169409,
#   'Afghanistan': 796255062975},
#  {'Civil unrest': 842955241147,
#   'Attack': 173815961506,
#   'Disease outbreak': 782389966709,
#   'Flood': 504567342880},
#  {'January': 789269779534,
#   'February': 898528197691,
#   'March': 341814020434,
#   'April': 582981880659,
#   'May': 881714492924,
#   'June': 842191546849,
#   'July': 225044240400,
#   'August': 637860132779,
#   'September': 327893498858,
#   'October': 81113368858,
#   'November': 715105976379,
#   'December': 321193061305},
#  {'Sindh': 1083570781771,
#   'Punjab': 115979017587,
#   'Balochistan': 491896530011,
#   'Khyber Pakhtunkhwa': 397587297653,
#   'Gilgit Baltistan': 405405895484,
#   'Azad Kashmir': 73319429031,
#   'Islamabad': 523233326767,
#   'Qinghai': 160138371888,
#   'Sichuan': 623798892277,
#   'Gansu': 275418627945,
#   'Heilongjiang': 874060229648,
#   'Yunnan': 1081167887854,
#   'Hunan': 1026562091902,
#   'Shaanxi': 137576383028,
#   'Hebei': 770066868597,
#   'Jilin': 69254807704,
#   'Hubei': 576287406604,
#   'Guizhou': 98018115111,
#   'Guangdong': 744228374843,
#   'Jiangxi': 167026942588,
#   'Henan': 50850142492,
#   'Shanxi': 813407145993,
#   'Shandong': 907788872740,
#   'Liaoning': 719227645152,
#   'Anhui': 598265670170,
#   'Fujian': 1096475016718,
#   'Jiangsu': 913033772429,
#   'Zhejiang': 592407251093,
#   'Taiwan': 186549519087,
#   'Hainan': 1072740311565,
#   'Hong Kong': 156063852278,
#   'Tibet': 27828004076,
#   'Beijing': 963432031780,
#   'Xinjiang': 373869605862,
#   'Suzhou': 184001692688,
#   'Andhra Pradesh': 1126945090,
#   'Arunachal Pradesh': 811076819656,
#   'Assam': 529774963214,
#   'Bihar': 850237536710,
#   'Chhattisgarh': 791859411120,
#   'Goa': 334409936205,
#   'Gujarat': 124006097873,
#   'Haryana': 437800888172,
#   'Himachal Pradesh': 485120184591,
#   'Jharkhand': 899478767606,
#   'Karnataka': 772981047552,
#   'Kerala': 338534963061,
#   'Madhya Pradesh': 660094512066,
#   'Maharashtra': 775392800431,
#   'Manipur': 1017390724292,
#   'Meghalaya': 27324212853,
#   'Mizoram': 1055454739204,
#   'Nagaland': 757212380018,
#   'Odisha': 588234578559,
#   'Rajasthan': 1070905881154,
#   'Sikkim': 462158184766,
#   'Tamil Nadu': 681767483263,
#   'Telangana': 212421497388,
#   'Tripura': 1021916151830,
#   'Uttar Pradesh': 722918171141,
#   'Uttarakhand': 306808806623,
#   'West Bengal': 467736529324,
#   'Andaman and Nicobar Islands': 841524758609,
#   'Chandigarh': 837048120871,
#   'Dadra & Nagar Haveli and Daman & Diu': 441577497574,
#   'Delhi': 611572722954,
#   'Kashmir': 1013418570070,
#   'Lakshadweep': 487695353223,
#   'Puducherry': 338678286169,
#   'Ladakh': 479538877861})

# %%
def getEvent(val): 
    for key, value in dEvents.items(): 
         if val == value: 
             return key
def getCountry(val): 
    for key, value in dCountries.items(): 
         if val == value: 
             return key
def getMonth(val): 
    for key, value in dMonths.items(): 
         if val == value: 
             return key
def getProvince(val): 
    for key, value in dProvince.items(): 
         if val == value: 
             return key

# %%
import csv
filename = "dataset.xls"#-------------------------INPUT

# %%
fields = []
rows = []

with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    
    fields = next(csvreader)
    
    for row in csvreader:
        rows.append(row)

# %%
rows
# Out:
# [['India', '2020', 'February', 'Civil unrest', 'Delhi'],
#  ['India', '2017', 'August', 'Civil unrest', 'Haryana'],
#  ['India', '2013', 'August', 'Civil unrest', 'Uttar Pradesh'],
#  ['India', '2006', 'May', 'Civil unrest', 'Gujarat'],
#  ['India', '2002', 'February', 'Civil unrest', 'Gujarat'],
#  ['India', '2003', 'February', 'Civil unrest', 'Assam'],
#  ['India', '2011', 'April', 'Civil unrest', 'Delhi'],
#  ['India', '2015', 'June', 'Civil unrest', 'Delhi'],
#  ['India', '2014', 'September', 'Civil unrest', 'West Bengal'],
#  ['India', '2016', 'February', 'Civil unrest', 'Haryana'],
#  ['India', '2018', 'August', 'Flood', 'Kerala'],
#  ['India', '2017', 'August', 'Flood', 'Maharashtra'],
#  ['India', '2017', 'July', 'Flood', 'Gujarat'],
#  ['India', '2017', 'July', 'Flood', 'West Bengal'],
#  ['India', '2017', 'August', 'Flood', 'Bihar'],
#  ['India', '2017', 'July', 'Flood', 'Assam'],
#  ['India', '2016', 'July', 'Flood', 'Assam'],
#  ['India', '2015', 'November', 'Flood', 'Tamil Nadu'],
#  ['India', '2015', 'June', 'Flood', 'Gujarat'],
#  ['India', '2015', 'August', 'Flood', 'Assam'],
#  ['India', '2014', 'September', 'Flood', 'Kashmir'],
#  ['India', '2007', 'August', 'Flood', 'Bihar'],
#  ['India', '2008', 'August', 'Flood', 'Bihar'],
#  ['India', '2019', 'May', 'Attack', 'Maharashtra'],
#  ['India', '2019', 'February', 'Attack', 'Kashmir'],
#  ['India', '2018', 'March', 'Attack', 'Chhattisgarh'],
#  ['India', '2018', 'February', 'Attack', 'Kashmir'],
#  ['India', '2017', 'July', 'Attack', 'Kashmir'],
#  ['India', '2017', 'April', 'Attack', 'Chhattisgarh'],
#  ['India', '2016', 'September', 'Attack', 'Kashmir'],
#  ['India', '2016', 'August', 'Attack', 'Assam'],
#  ['India', '2016', 'January', 'Attack', 'Punjab'],
#  ['India', '2015', 'July', 'Attack', 'Punjab'],
#  ['India', '2015', 'June', 'Attack', 'Manipur'],
#  ['India', '2014', 'December', 'Attack', 'Assam'],
#  ['India', '2014', 'May', 'Attack', 'Jharkhand'],
#  ['India', '2014', 'May', 'Attack', 'Assam'],
#  ['India', '2014', 'April', 'Attack', 'Jharkhand'],
#  ['India', '2014', 'March', 'Attack', 'Chhattisgarh'],
#  ['India', '2018', 'May', 'Disease outbreak', 'Kerala'],
#  ['India', '2002', 'February', 'Disease outbreak', 'Himachal Pradesh'],
#  ['India', '2017', 'May', 'Disease outbreak', 'Gujarat'],
#  ['India', '2006', 'February', 'Disease outbreak', 'Karnataka'],
#  ['India', '2006', 'February', 'Disease outbreak', 'Maharashtra'],
#  ['India', '2005', 'July', 'Disease outbreak', 'Uttar Pradesh'],
#  ['India', '2005', 'March', 'Disease outbreak', 'Delhi'],
#  ['India', '2003', 'June', 'Disease outbreak', 'Delhi'],
#  ['India', '2003', 'April', 'Disease outbreak', 'Maharashtra'],
#  ['India', '2001', 'July', 'Disease outbreak', 'Odisha'],
#  ['China', '2019', 'October', 'Civil unrest', 'Hong Kong'],
#  ['China', '2011', 'September', 'Civil unrest', 'Guangdong'],
#  ['China', '2008', 'March', 'Civil unrest', 'Tibet'],
#  ['China', '2009', 'July', 'Civil unrest', 'Xinjiang'],
#  ['China', '2008', 'March', 'Civil unrest', 'Sichuan'],
#  ['China', '2012', 'June', 'Civil unrest', 'Guangdong'],
#  ['China', '2011', 'November', 'Civil unrest', 'Guangdong'],
#  ['China', '2011', 'March', 'Civil unrest', 'Yunnan'],
#  ['China', '2010', 'January', 'Civil unrest', 'Suzhou'],
#  ['China', '2008', 'June', 'Civil unrest', 'Guizhou'],
#  ['China', '2020', 'January', 'Disease outbreak', 'Hubei'],
#  ['China', '2018', 'February', 'Disease outbreak', 'Jiangsu'],
#  ['China', '2016', 'January', 'Disease outbreak', 'Guangdong'],
#  ['China', '2016', 'April', 'Disease outbreak', 'Guangdong'],
#  ['China', '2016', 'March', 'Disease outbreak', 'Beijing'],
#  ['China', '2017', 'January', 'Disease outbreak', 'Hong Kong'],
#  ['China', '2015', 'January', 'Disease outbreak', 'Fujian'],
#  ['China', '2015', 'January', 'Disease outbreak', 'Yunnan'],
#  ['China', '2014', 'January', 'Disease outbreak', 'Zhejiang'],
#  ['China', '2014', 'December', 'Disease outbreak', 'Guangdong'],
#  ['China', '2019', 'July', 'Flood', 'Beijing'],
#  ['China', '2018', 'July', 'Flood', 'Gansu'],
#  ['China', '2018', 'June', 'Flood', 'Guangdong'],
#  ['China', '2017', 'June', 'Flood', 'Hunan'],
#  ['China', '2017', 'June', 'Flood', 'Guizhou'],
#  ['China', '2016', 'July', 'Flood', 'Hubei'],
#  ['China', '2015', 'June', 'Flood', 'Jiangsu'],
#  ['China', '2015', 'June', 'Flood', 'Hubei'],
#  ['China', '2013', 'July', 'Flood', 'Sichuan'],
#  ['China', '2013', 'July', 'Flood', 'Beijing'],
#  ['China', '2016', 'December', 'Attack', 'Xinjiang'],
#  ['China', '2015', 'June', 'Attack', 'Xinjiang'],
#  ['China', '2014', 'March', 'Attack', 'Yunnan'],
#  ['China', '2013', 'October', 'Attack', 'Beijing'],
#  ['China', '2013', 'April', 'Attack', 'Xinjiang'],
#  ['China', '2011', 'July', 'Attack', 'Xinjiang'],
#  ['China', '2002', 'April', 'Attack', 'Sichuan'],
#  ['China', '2001', 'March', 'Attack', 'Hebei'],
#  ['China', '2007', 'January', 'Attack', 'Xinjiang'],
#  ['China', '2008', 'August', 'Attack', 'Xinjiang'],
#  ['Pakistan', '2010', 'May', 'Civil unrest', 'Sindh'],
#  ['Pakistan', '2007', 'December', 'Civil unrest', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2007', 'December', 'Civil unrest', 'Punjab'],
#  ['Pakistan', '2007', 'December', 'Civil unrest', 'Sindh'],
#  ['Pakistan', '2010', 'August', 'Civil unrest', 'Sindh'],
#  ['Pakistan', '1972', 'July', 'Civil unrest', 'Sindh'],
#  ['Pakistan', '2011', 'July', 'Civil unrest', 'Sindh'],
#  ['Pakistan', '2011', 'August', 'Civil unrest', 'Sindh'],
#  ['Pakistan', '2019', 'May', 'Attack', 'Punjab'],
#  ['Pakistan', '2019', 'April', 'Attack', 'Balochistan'],
#  ['Pakistan', '2019', 'January', 'Attack', 'Balochistan'],
#  ['Pakistan', '2019', 'January', 'Attack', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2018', 'January', 'Attack', 'Balochistan'],
#  ['Pakistan', '2018', 'February', 'Attack', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2018', 'March', 'Attack', 'Punjab'],
#  ['Pakistan', '2018', 'April', 'Attack', 'Balochistan'],
#  ['Pakistan', '2018', 'July', 'Attack', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2018', 'July', 'Attack', 'Balochistan'],
#  ['Pakistan', '2018', 'October', 'Attack', 'Balochistan'],
#  ['Pakistan', '2017', 'January', 'Attack', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2017', 'February', 'Attack', 'Punjab'],
#  ['Pakistan', '2017', 'February', 'Attack', 'Sindh'],
#  ['Pakistan', '2017', 'March', 'Attack', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2017', 'March', 'Attack', 'Balochistan'],
#  ['Pakistan', '2017', 'June', 'Attack', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2017', 'July', 'Attack', 'Punjab'],
#  ['Pakistan', '2017', 'August', 'Attack', 'Balochistan'],
#  ['Pakistan', '2017', 'October', 'Attack', 'Balochistan'],
#  ['Pakistan', '2017', 'December', 'Attack', 'Balochistan'],
#  ['Pakistan', '2019', 'July', 'Disease outbreak', 'Gilgit Baltistan'],
#  ['Pakistan', '2019', 'July', 'Disease outbreak', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2019', 'April', 'Disease outbreak', 'Sindh'],
#  ['Pakistan', '2016', 'October', 'Disease outbreak', 'Balochistan'],
#  ['Pakistan', '2011', 'June', 'Disease outbreak', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2010', 'September', 'Disease outbreak', 'Sindh'],
#  ['Pakistan', '2010', 'September', 'Disease outbreak', 'Punjab'],
#  ['Pakistan', '2010', 'September', 'Disease outbreak', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2007', 'November', 'Disease outbreak', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2014', 'September', 'Flood', 'Punjab'],
#  ['Pakistan', '2013', 'August', 'Flood', 'Punjab'],
#  ['Pakistan', '2013', 'August', 'Flood', 'Balochistan'],
#  ['Pakistan', '2013', 'August', 'Flood', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2013', 'August', 'Flood', 'Sindh'],
#  ['Pakistan', '2012', 'September', 'Flood', 'Sindh'],
#  ['Pakistan', '2012', 'September', 'Flood', 'Punjab'],
#  ['Pakistan', '2012', 'September', 'Flood', 'Balochistan'],
#  ['Pakistan', '2012', 'September', 'Flood', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2011', 'August', 'Flood', 'Sindh'],
#  ['Pakistan', '2010', 'July', 'Flood', 'Sindh'],
#  ['Pakistan', '2010', 'July', 'Flood', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2010', 'July', 'Flood', 'Balochistan'],
#  ['Pakistan', '2010', 'July', 'Flood', 'Gilgit Baltistan'],
#  ['Pakistan', '2010', 'July', 'Flood', 'Punjab'],
#  ['Pakistan', '2019', 'September', 'Flood', 'Khyber Pakhtunkhwa'],
#  ['Pakistan', '2017', 'August', 'Flood', 'Sindh']]

# %%
hashRows = []
for country, year, month, event, province in rows:
    hashRows.append([ str(dCountries[country]), year, str(dMonths[month]), str(dEvents[event]), str(dProvince[province]) ])

# %%
hashRows
# Out:
# [['599540218941', '2020', '898528197691', '842955241147', '611572722954'],
#  ['599540218941', '2017', '637860132779', '842955241147', '437800888172'],
#  ['599540218941', '2013', '637860132779', '842955241147', '722918171141'],
#  ['599540218941', '2006', '881714492924', '842955241147', '124006097873'],
#  ['599540218941', '2002', '898528197691', '842955241147', '124006097873'],
#  ['599540218941', '2003', '898528197691', '842955241147', '529774963214'],
#  ['599540218941', '2011', '582981880659', '842955241147', '611572722954'],
#  ['599540218941', '2015', '842191546849', '842955241147', '611572722954'],
#  ['599540218941', '2014', '327893498858', '842955241147', '467736529324'],
#  ['599540218941', '2016', '898528197691', '842955241147', '437800888172'],
#  ['599540218941', '2018', '637860132779', '504567342880', '338534963061'],
#  ['599540218941', '2017', '637860132779', '504567342880', '775392800431'],
#  ['599540218941', '2017', '225044240400', '504567342880', '124006097873'],
#  ['599540218941', '2017', '225044240400', '504567342880', '467736529324'],
#  ['599540218941', '2017', '637860132779', '504567342880', '850237536710'],
#  ['599540218941', '2017', '225044240400', '504567342880', '529774963214'],
#  ['599540218941', '2016', '225044240400', '504567342880', '529774963214'],
#  ['599540218941', '2015', '715105976379', '504567342880', '681767483263'],
#  ['599540218941', '2015', '842191546849', '504567342880', '124006097873'],
#  ['599540218941', '2015', '637860132779', '504567342880', '529774963214'],
#  ['599540218941', '2014', '327893498858', '504567342880', '1013418570070'],
#  ['599540218941', '2007', '637860132779', '504567342880', '850237536710'],
#  ['599540218941', '2008', '637860132779', '504567342880', '850237536710'],
#  ['599540218941', '2019', '881714492924', '173815961506', '775392800431'],
#  ['599540218941', '2019', '898528197691', '173815961506', '1013418570070'],
#  ['599540218941', '2018', '341814020434', '173815961506', '791859411120'],
#  ['599540218941', '2018', '898528197691', '173815961506', '1013418570070'],
#  ['599540218941', '2017', '225044240400', '173815961506', '1013418570070'],
#  ['599540218941', '2017', '582981880659', '173815961506', '791859411120'],
#  ['599540218941', '2016', '327893498858', '173815961506', '1013418570070'],
#  ['599540218941', '2016', '637860132779', '173815961506', '529774963214'],
#  ['599540218941', '2016', '789269779534', '173815961506', '115979017587'],
#  ['599540218941', '2015', '225044240400', '173815961506', '115979017587'],
#  ['599540218941', '2015', '842191546849', '173815961506', '1017390724292'],
#  ['805650366791', '2013', '637860132779', '504567342880', '115979017587'],
#  ['805650366791', '2013', '637860132779', '504567342880', '491896530011'],
#  ['805650366791', '2013', '637860132779', '504567342880', '397587297653'],
#  ['805650366791', '2013', '637860132779', '504567342880', '1083570781771'],
#  ['805650366791', '2012', '327893498858', '504567342880', '1083570781771'],
#  ['805650366791', '2012', '327893498858', '504567342880', '115979017587'],
#  ['805650366791', '2012', '327893498858', '504567342880', '491896530011'],
#  ['805650366791', '2012', '327893498858', '504567342880', '397587297653'],
#  ['805650366791', '2011', '637860132779', '504567342880', '1083570781771'],
#  ['805650366791', '2010', '225044240400', '504567342880', '1083570781771'],
#  ['805650366791', '2010', '225044240400', '504567342880', '397587297653'],
#  ['805650366791', '2010', '225044240400', '504567342880', '491896530011'],
#  ['805650366791', '2010', '225044240400', '504567342880', '405405895484'],
#  ['805650366791', '2010', '225044240400', '504567342880', '115979017587'],
#  ['805650366791', '2019', '327893498858', '504567342880', '397587297653'],
#  ['805650366791', '2017', '637860132779', '504567342880', '1083570781771']]

# %%
filename2 = "dsHash2.csv"
with open(filename2, 'w') as csvfile2:
    csvwriter = csv.writer(csvfile2, delimiter=',', lineterminator='\r')
    csvwriter.writerow(fields)
    csvwriter.writerows(hashRows)

# %%
filename2
# Out:
# 'dsHash2.csv'

# %%
csvfile.close()
csvfile2.close()

# %%
fields = []
rows2 = []
filename = "dsHash2.csv"
with open(filename, 'r', encoding = 'utf-8') as csvfile:
    csvreader = csv.reader(csvfile)
    
    fields = next(csvreader)
    
    for row in csvreader:
        rows2.append(row)

# %%
rows2
# Out:
# [['599540218941', '2020', '898528197691', '842955241147', '611572722954'],
#  ['599540218941', '2017', '637860132779', '842955241147', '437800888172'],
#  ['599540218941', '2013', '637860132779', '842955241147', '722918171141'],
#  ['599540218941', '2006', '881714492924', '842955241147', '124006097873'],
#  ['599540218941', '2002', '898528197691', '842955241147', '124006097873'],
#  ['599540218941', '2003', '898528197691', '842955241147', '529774963214'],
#  ['599540218941', '2011', '582981880659', '842955241147', '611572722954'],
#  ['599540218941', '2015', '842191546849', '842955241147', '611572722954'],
#  ['599540218941', '2014', '327893498858', '842955241147', '467736529324'],
#  ['599540218941', '2016', '898528197691', '842955241147', '437800888172'],
#  ['599540218941', '2018', '637860132779', '504567342880', '338534963061'],
#  ['599540218941', '2017', '637860132779', '504567342880', '775392800431'],
#  ['599540218941', '2017', '225044240400', '504567342880', '124006097873'],
#  ['599540218941', '2017', '225044240400', '504567342880', '467736529324'],
#  ['599540218941', '2017', '637860132779', '504567342880', '850237536710'],
#  ['599540218941', '2017', '225044240400', '504567342880', '529774963214'],
#  ['599540218941', '2016', '225044240400', '504567342880', '529774963214'],
#  ['599540218941', '2015', '715105976379', '504567342880', '681767483263'],
#  ['599540218941', '2015', '842191546849', '504567342880', '124006097873'],
#  ['599540218941', '2015', '637860132779', '504567342880', '529774963214'],
#  ['599540218941', '2014', '327893498858', '504567342880', '1013418570070'],
#  ['599540218941', '2007', '637860132779', '504567342880', '850237536710'],
#  ['599540218941', '2008', '637860132779', '504567342880', '850237536710'],
#  ['805650366791', '2017', '81113368858', '173815961506', '491896530011'],
#  ['805650366791', '2017', '321193061305', '173815961506', '491896530011'],
#  ['805650366791', '2019', '225044240400', '782389966709', '405405895484'],
#  ['805650366791', '2019', '225044240400', '782389966709', '397587297653'],
#  ['805650366791', '2019', '582981880659', '782389966709', '1083570781771'],
#  ['805650366791', '2016', '81113368858', '782389966709', '491896530011'],
#  ['805650366791', '2011', '842191546849', '782389966709', '397587297653'],
#  ['805650366791', '2010', '327893498858', '782389966709', '1083570781771'],
#  ['805650366791', '2010', '327893498858', '782389966709', '115979017587'],
#  ['805650366791', '2010', '327893498858', '782389966709', '397587297653'],
#  ['805650366791', '2007', '715105976379', '782389966709', '397587297653'],
#  ['805650366791', '2014', '327893498858', '504567342880', '115979017587'],
#  ['805650366791', '2013', '637860132779', '504567342880', '115979017587'],
#  ['805650366791', '2013', '637860132779', '504567342880', '491896530011'],
#  ['805650366791', '2013', '637860132779', '504567342880', '397587297653'],
#  ['805650366791', '2013', '637860132779', '504567342880', '1083570781771'],
#  ['805650366791', '2012', '327893498858', '504567342880', '1083570781771'],
#  ['805650366791', '2012', '327893498858', '504567342880', '115979017587'],
#  ['805650366791', '2012', '327893498858', '504567342880', '491896530011'],
#  ['805650366791', '2012', '327893498858', '504567342880', '397587297653'],
#  ['805650366791', '2011', '637860132779', '504567342880', '1083570781771'],
#  ['805650366791', '2010', '225044240400', '504567342880', '1083570781771'],
#  ['805650366791', '2010', '225044240400', '504567342880', '397587297653'],
#  ['805650366791', '2010', '225044240400', '504567342880', '491896530011'],
#  ['805650366791', '2010', '225044240400', '504567342880', '405405895484'],
#  ['805650366791', '2010', '225044240400', '504567342880', '115979017587'],
#  ['805650366791', '2019', '327893498858', '504567342880', '397587297653'],
#  ['805650366791', '2017', '637860132779', '504567342880', '1083570781771']]

# %%
getCountry(599540218941)
# Out:
# 'India'

# %%
#Now training the model using training data---------------------------------------------------#

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("dsHash2.csv")
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#           Country  Year         Month         Event  State/Province
# 0    599540218941  2020  898528197691  842955241147    611572722954
# 1    599540218941  2017  637860132779  842955241147    437800888172
# 2    599540218941  2013  637860132779  842955241147    722918171141
# 3    599540218941  2006  881714492924  842955241147    124006097873
# 4    599540218941  2002  898528197691  842955241147    124006097873
# ..            ...   ...           ...           ...             ...
# 139  805650366791  2010  225044240400  504567342880    491896530011
# 140  805650366791  2010  225044240400  504567342880    405405895484
# 141  805650366791  2010  225044240400  504567342880    115979017587
# 142  805650366791  2019  327893498858  504567342880    397587297653
# 143  805650366791  2017  637860132779  504567342880   1083570781771
#
# [144 rows x 5 columns]

# %%
#df.Country.astype(int)
df['State/Province']
# Out:
# 0       611572722954
# 1       437800888172
# 2       722918171141
# 3       124006097873
# 4       124006097873
#            ...
# 139     491896530011
# 140     405405895484
# 141     115979017587
# 142     397587297653
# 143    1083570781771
# Name: State/Province, Length: 144, dtype: int64

# %%
x=df[['Country','Year','Month','State/Province']]
y=df['Event']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0)

# %%
#predicting result using decision tree &
#predicting result using KNN, Naive Bayes
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 


#1. Decision Tree -----------------------------
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)
#predicting
dtree_predictions = dtree_model.predict(x_test)


# creating a confusion matrix 
cm = confusion_matrix(y_test, dtree_predictions)

# %%
dtree_predictions
# Out:
# array([173815961506, 842955241147, 173815961506, 173815961506,
#        173815961506, 504567342880, 173815961506, 842955241147,
#        504567342880, 173815961506, 842955241147, 173815961506,
#        842955241147, 842955241147, 504567342880, 173815961506,
#        173815961506, 173815961506, 173815961506, 842955241147,
#        842955241147, 173815961506, 173815961506, 842955241147,
#        842955241147, 173815961506, 173815961506, 842955241147,
#        173815961506, 173815961506, 173815961506, 173815961506,
#        842955241147, 504567342880, 173815961506, 173815961506],
#       dtype=int64)

# %%
cm#Dtree Confusion matrix
# Out:
# array([[10,  0,  0,  1],
#        [ 5,  2,  0,  3],
#        [ 4,  0,  0,  4],
#        [ 2,  2,  0,  3]], dtype=int64)

# %%
# predicting result using KNN--------------------

# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(x_train, y_train) 
  
# accuracy on X_test 
accuracy = knn.score(x_test, y_test) 
#print (accuracy) 
  
# creating a confusion matrix 
knn_predictions = knn.predict(x_test)  
cm = confusion_matrix(y_test, knn_predictions) 

accuracy#Accuracy using KNN
# Out:
# 0.19444444444444445

# %%
cm#KNN Confusion matrix
# Out:
# array([[2, 6, 1, 2],
#        [5, 4, 0, 1],
#        [4, 2, 1, 1],
#        [3, 4, 0, 0]], dtype=int64)

# %%
# predicting result using Naive Bayes----------------

# training a Naive Bayes classifier 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB().fit(x_train, y_train) 
gnb_predictions = gnb.predict(x_test)

# %%
# accuracy on X_test 
accuracy = gnb.score(x_test, y_test)  
# creating a confusion matrix 
cm = confusion_matrix(y_test, gnb_predictions) 

accuracy#Accuracy using Naive Bayes
# Out:
# 0.2222222222222222

# %%
cm#Naive Bayes Confusion matrix
# Out:
# array([[4, 3, 3, 1],
#        [9, 1, 0, 0],
#        [5, 2, 1, 0],
#        [4, 1, 0, 2]], dtype=int64)

# %%
#1. DT
def predictDTree(country, year, month, province):
    result = dtree_model.predict([ [dCountries[country], 2020, dMonths[month], dProvince[province] ] ])
    return getEvent(result)

a = predictDTree('India', 2020, 'June', 'Maharashtra')

# %%
def predictKNN(country, year, month, province):
    result = knn.predict([ [dCountries[country], 2020, dMonths[month], dProvince[province] ] ])
    return getEvent(result)

b = predictKNN('India', 2020, 'June', 'West Bengal')

# %%
def predictGNB(country, year, month, province):
    result = gnb.predict([ [dCountries[country], 2020, dMonths[month], dProvince[province] ] ])
    return getEvent(result)
c = predictGNB('India', 2020, 'June', 'Odisha')

# %%
a, b, c
# Out:
# ('Attack', 'Civil unrest', 'Attack')
